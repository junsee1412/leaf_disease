# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/note/LeafDD
# Out:
# /content/drive/MyDrive/note/LeafDD

# %%
# !ls datasets/
# Out:
# Cerscospora  Healthy  Miner  Phoma  Rust

# %%
import numpy as np
import tensorflow as tf
import cv2, os
from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
from keras.utils.image_utils import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
from keras.optimizers import SGD, schedules

# %%
class SimpleDatasetLoader:
    def __init__(self, preprocessors=None):
        # Lưu ảnh tiền xử lý
        self.preprocessors = preprocessors

        # Nếu bước tiền xử lý là None thì khởi tạo danh sách rỗng
        if self.preprocessors is None:
            self.preprocessors = []

    def load(self, imagePaths, verbose=-1):
        # Khởi tạo danh sách các đặc trưng và nhãn
        data = []
        labels = []

        # Lặp qua tất cả ảnh đầu vào
        for (i, imagePath) in enumerate(imagePaths):
            # Nạp ảnh và trích xuất nhãn từ đường dẫn định dạng
            # /path/to/dataset/{class}/{image}.jpg
            image = cv2.imread(imagePath)
            label = imagePath.split(os.path.sep)[-2]
            # check to see if our preprocessors are not None
            if self.preprocessors is not None:
                # Lặp qua tất cả tiền xử lý và áp dụng cho mỗi ảnh
                for p in self.preprocessors:
                    image = p.preprocess(image)
            # Mỗi ảnh được xử lý là vector đặc trưng bằng cách
            # cập nhật danh sách dữ liệu cùng với nhãn
            data.append(image)
            labels.append(label)

            # Hiển thị ảnh cập nhật
            if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
               print("[INFO] Đã xử lý {}/{}".format(i + 1,len(imagePaths)))
                # Trả về dữ liệu kiểu tuple gồm dữ liệu và nhãn
        return (np.array(data), np.array(labels))

# %%
class ImageToArrayPreprocessor:  # Tạo lớp để chuyển ảnh --> mảng
    def __init__(self, dataFormat=None):
        # Lưu ảnh đã được định dạng
        self.dataFormat = dataFormat

    def preprocess(self, image): # Định nghĩa phương thức preprocess trả về mảng
        # Hàm img_to_array của Keras
        return img_to_array(image, data_format=self.dataFormat)
class SimplePreprocessor:
    def __init__(self, width, height, inter=cv2.INTER_AREA):
        # Lưu image width, height và interpolation
        self.width = width
        self.height = height
        self.inter = inter

    def preprocess(self, image):
        # Trả về ảnh có kích thước đã thay đổi
        return cv2.resize(image, (self.width, self.height), interpolation=self.inter)

# %%
class ShallowNet:
    @staticmethod
    def build(width, height, depth, classes):
        # khởi tạo mô hình
        # height, width, depth: tương ứng 3 chiều của dữ liệu ảnh đầu vào
        # classes: tổng số lớp mà mạng dự đoán, phụ thuộc vào dữ liệu
        # Dữ liệu Animal: 3 lớp; Dữ liệu CIFAR-10: 10 lớp

        model = Sequential()
        inputShape = (height, width, depth)

        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)

        # Định nghĩa mạng CONV => RELU layer
        model.add(Conv2D(32, (3, 3), padding="same",input_shape = inputShape))
        model.add(Activation("relu"))

        # Bộ phân lớp sử dụng hàm softmax
        model.add(Flatten())       # Chuyển thành vector
        model.add(Dense(classes))  # Định nghĩa Full Connected layer
        model.add(Activation("softmax"))   # Kích hoạt hàm softmax để phân lớp
        # Trả về model kiến trúc mạng
        return model

# %%
class MiniVGGNet:
  @staticmethod
  def build(width, height, depth, classes):
      # Khởi tạo mô hình, shape ảnh đầu vào và số kênh của ảnh đầu vào
      model = Sequential()
      input_shape = (height, width, depth)
      channel_dim = -1  # chỉ số của số kênh ảnh đầu vào
                        # giá trị -1 ý muốn nói chỉ số kênh nằm cuối cùng
                        # của danh sách chứa dữ liệu ảnh đầu vào

      # sử dụng 'channels_first' để cập nhật shape và số kênh ảnh đầu vào
      if K.image_data_format() == 'channels_first':
          input_shape = (depth, height, width)
          channel_dim = 1

      # Chuỗi layer đầu tiên  CONV => RELU => CONV => RELU => POOL
      model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(Conv2D(32, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(MaxPooling2D(pool_size=(2, 2)))
      model.add(Dropout(0.25))

      # Chuỗi layer thứ hai CONV => RELU => CONV => RELU => POOL
      model.add(Conv2D(64, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(Conv2D(64, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(MaxPooling2D(pool_size=(2, 2)))
      model.add(Dropout(0.25))

      # Thiết lập FC thứ nhất => RELU layers
      model.add(Flatten())
      model.add(Dense(512))
      model.add(Activation('relu'))
      model.add(BatchNormalization())
      model.add(Dropout(0.25))   # Dropout 50%

      # THiết lập FC thứ hai => Hàm phân lớp Softmax
      model.add(Dense(classes))
      model.add(Activation('softmax'))

      # Trả về kiến trúc mạng/mô hình
      return model

# %%
class ModVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        # Khởi tạo mô hình, shape ảnh đầu vào và số kênh của ảnh đầu vào
        model = Sequential()
        input_shape = (height, width, depth)
        channel_dim = -1  # chỉ số của số kênh ảnh đầu vào
                          # giá trị -1 ý muốn nói chỉ số kênh nằm cuối cùng
                          # của danh sách chứa dữ liệu ảnh đầu vào

        # sử dụng 'channels_first' để cập nhật shape và số kênh ảnh đầu vào
        if K.image_data_format() == 'channels_first':
            input_shape = (depth, height, width)
            channel_dim = 1

        # Chuỗi layer đầu tiên  CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(32, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Chuỗi layer thứ hai CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(64, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(64, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Chuỗi layer thứ ba CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(128, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(128, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Thiết lập FC thứ nhất => RELU layers
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))   # Dropout 50%

        # THiết lập FC thứ hai => Hàm phân lớp Softmax
        model.add(Dense(classes))
        model.add(Activation('softmax'))

        # Trả về kiến trúc mạng/mô hình
        return model

# %%
vb = 20

imagePaths = list(paths.list_images("datasets/"))

# Bước 1. Chuẩn bị dữ liệu
# Khởi tạo tiền xử lý ảnh
sp = SimplePreprocessor(32, 32) # Thiết lập kích thước ảnh 32 x 32
iap = ImageToArrayPreprocessor() # Gọi hàm để chuyển ảnh sang mảng

# Nạp dataset từ đĩa
print("[INFO] Nạp ảnh...")

sdl = SimpleDatasetLoader(preprocessors=[sp, iap])
(data, labels) = sdl.load(imagePaths, verbose=vb)
data = data.astype("float") / 255.0
# Out:
# [INFO] Nạp ảnh...
# [INFO] Đã xử lý 20/9120
# [INFO] Đã xử lý 40/9120
# [INFO] Đã xử lý 60/9120
# [INFO] Đã xử lý 80/9120
# [INFO] Đã xử lý 100/9120
# [INFO] Đã xử lý 120/9120
# [INFO] Đã xử lý 140/9120
# [INFO] Đã xử lý 160/9120
# [INFO] Đã xử lý 180/9120
# [INFO] Đã xử lý 200/9120
# [INFO] Đã xử lý 220/9120
# [INFO] Đã xử lý 240/9120
# [INFO] Đã xử lý 260/9120
# [INFO] Đã xử lý 280/9120
# [INFO] Đã xử lý 300/9120
# [INFO] Đã xử lý 320/9120
# [INFO] Đã xử lý 340/9120
# [INFO] Đã xử lý 360/9120
# [INFO] Đã xử lý 380/9120
# [INFO] Đã xử lý 400/9120
# [INFO] Đã xử lý 420/9120
# [INFO] Đã xử lý 440/9120
# [INFO] Đã xử lý 460/9120
# [INFO] Đã xử lý 480/9120
# [INFO] Đã xử lý 500/9120
# [INFO] Đã xử lý 520/9120
# [INFO] Đã xử lý 540/9120
# [INFO] Đã xử lý 560/9120
# [INFO] Đã xử lý 580/9120
# [INFO] Đã xử lý 600/9120
# [INFO] Đã xử lý 620/9120
# [INFO] Đã xử lý 640/9120
# [INFO] Đã xử lý 660/9120
# [INFO] Đã xử lý 680/9120
# [INFO] Đã xử lý 700/9120
# [INFO] Đã xử lý 720/9120
# [INFO] Đã xử lý 740/9120
# [INFO] Đã xử lý 760/9120
# [INFO] Đã xử lý 780/9120
# [INFO] Đã xử lý 800/9120
# [INFO] Đã xử lý 820/9120
# [INFO] Đã xử lý 840/9120
# [INFO] Đã xử lý 860/9120
# [INFO] Đã xử lý 880/9120
# [INFO] Đã xử lý 900/9120
# [INFO] Đã xử lý 920/9120
# [INFO] Đã xử lý 940/9120
# [INFO] Đã xử lý 960/9120
# [INFO] Đã xử lý 980/9120
# [INFO] Đã xử lý 1000/9120
# [INFO] Đã xử lý 1020/9120
# [INFO] Đã xử lý 1040/9120
# [INFO] Đã xử lý 1060/9120
# [INFO] Đã xử lý 1080/9120
# [INFO] Đã xử lý 1100/9120
# [INFO] Đã xử lý 1120/9120
# [INFO] Đã xử lý 1140/9120
# [INFO] Đã xử lý 1160/9120
# [INFO] Đã xử lý 1180/9120
# [INFO] Đã xử lý 1200/9120
# [INFO] Đã xử lý 1220/9120
# [INFO] Đã xử lý 1240/9120
# [INFO] Đã xử lý 1260/9120
# [INFO] Đã xử lý 1280/9120
# [INFO] Đã xử lý 1300/9120
# [INFO] Đã xử lý 1320/9120
# [INFO] Đã xử lý 1340/9120
# [INFO] Đã xử lý 1360/9120
# [INFO] Đã xử lý 1380/9120
# [INFO] Đã xử lý 1400/9120
# [INFO] Đã xử lý 1420/9120
# [INFO] Đã xử lý 1440/9120
# [INFO] Đã xử lý 1460/9120
# [INFO] Đã xử lý 1480/9120
# [INFO] Đã xử lý 1500/9120
# [INFO] Đã xử lý 1520/9120
# [INFO] Đã xử lý 1540/9120
# [INFO] Đã xử lý 1560/9120
# [INFO] Đã xử lý 1580/9120
# [INFO] Đã xử lý 1600/9120
# [INFO] Đã xử lý 1620/9120
# [INFO] Đã xử lý 1640/9120
# [INFO] Đã xử lý 1660/9120
# [INFO] Đã xử lý 1680/9120
# [INFO] Đã xử lý 1700/9120
# [INFO] Đã xử lý 1720/9120
# [INFO] Đã xử lý 1740/9120
# [INFO] Đã xử lý 1760/9120
# [INFO] Đã xử lý 1780/9120
# [INFO] Đã xử lý 1800/9120
# [INFO] Đã xử lý 1820/9120
# [INFO] Đã xử lý 1840/9120
# [INFO] Đã xử lý 1860/9120
# [INFO] Đã xử lý 1880/9120
# [INFO] Đã xử lý 1900/9120
# [INFO] Đã xử lý 1920/9120
# [INFO] Đã xử lý 1940/9120
# [INFO] Đã xử lý 1960/9120
# [INFO] Đã xử lý 1980/9120
# [INFO] Đã xử lý 2000/9120
# [INFO] Đã xử lý 2020/9120
# [INFO] Đã xử lý 2040/9120
# [INFO] Đã xử lý 2060/9120
# [INFO] Đã xử lý 2080/9120
# [INFO] Đã xử lý 2100/9120
# [INFO] Đã xử lý 2120/9120
# [INFO] Đã xử lý 2140/9120
# [INFO] Đã xử lý 2160/9120
# [INFO] Đã xử lý 2180/9120
# [INFO] Đã xử lý 2200/9120
# [INFO] Đã xử lý 2220/9120
# [INFO] Đã xử lý 2240/9120
# [INFO] Đã xử lý 2260/9120
# [INFO] Đã xử lý 2280/9120
# [INFO] Đã xử lý 2300/9120
# [INFO] Đã xử lý 2320/9120
# [INFO] Đã xử lý 2340/9120
# [INFO] Đã xử lý 2360/9120
# [INFO] Đã xử lý 2380/9120
# [INFO] Đã xử lý 2400/9120
# [INFO] Đã xử lý 2420/9120
# [INFO] Đã xử lý 2440/9120
# [INFO] Đã xử lý 2460/9120
# [INFO] Đã xử lý 2480/9120
# [INFO] Đã xử lý 2500/9120
# [INFO] Đã xử lý 2520/9120
# [INFO] Đã xử lý 2540/9120
# [INFO] Đã xử lý 2560/9120
# [INFO] Đã xử lý 2580/9120
# [INFO] Đã xử lý 2600/9120
# [INFO] Đã xử lý 2620/9120
# [INFO] Đã xử lý 2640/9120
# [INFO] Đã xử lý 2660/9120
# [INFO] Đã xử lý 2680/9120
# [INFO] Đã xử lý 2700/9120
# [INFO] Đã xử lý 2720/9120
# [INFO] Đã xử lý 2740/9120
# [INFO] Đã xử lý 2760/9120
# [INFO] Đã xử lý 2780/9120
# [INFO] Đã xử lý 2800/9120
# [INFO] Đã xử lý 2820/9120
# [INFO] Đã xử lý 2840/9120
# [INFO] Đã xử lý 2860/9120
# [INFO] Đã xử lý 2880/9120
# [INFO] Đã xử lý 2900/9120
# [INFO] Đã xử lý 2920/9120
# [INFO] Đã xử lý 2940/9120
# [INFO] Đã xử lý 2960/9120
# [INFO] Đã xử lý 2980/9120
# [INFO] Đã xử lý 3000/9120
# [INFO] Đã xử lý 3020/9120
# [INFO] Đã xử lý 3040/9120
# [INFO] Đã xử lý 3060/9120
# [INFO] Đã xử lý 3080/9120
# [INFO] Đã xử lý 3100/9120
# [INFO] Đã xử lý 3120/9120
# [INFO] Đã xử lý 3140/9120
# [INFO] Đã xử lý 3160/9120
# [INFO] Đã xử lý 3180/9120
# [INFO] Đã xử lý 3200/9120
# [INFO] Đã xử lý 3220/9120
# [INFO] Đã xử lý 3240/9120
# [INFO] Đã xử lý 3260/9120
# [INFO] Đã xử lý 3280/9120
# [INFO] Đã xử lý 3300/9120
# [INFO] Đã xử lý 3320/9120
# [INFO] Đã xử lý 3340/9120
# [INFO] Đã xử lý 3360/9120
# [INFO] Đã xử lý 3380/9120
# [INFO] Đã xử lý 3400/9120
# [INFO] Đã xử lý 3420/9120
# [INFO] Đã xử lý 3440/9120
# [INFO] Đã xử lý 3460/9120
# [INFO] Đã xử lý 3480/9120
# [INFO] Đã xử lý 3500/9120
# [INFO] Đã xử lý 3520/9120
# [INFO] Đã xử lý 3540/9120
# [INFO] Đã xử lý 3560/9120
# [INFO] Đã xử lý 3580/9120
# [INFO] Đã xử lý 3600/9120
# [INFO] Đã xử lý 3620/9120
# [INFO] Đã xử lý 3640/9120
# [INFO] Đã xử lý 3660/9120
# [INFO] Đã xử lý 3680/9120
# [INFO] Đã xử lý 3700/9120
# [INFO] Đã xử lý 3720/9120
# [INFO] Đã xử lý 3740/9120
# [INFO] Đã xử lý 3760/9120
# [INFO] Đã xử lý 3780/9120
# [INFO] Đã xử lý 3800/9120
# [INFO] Đã xử lý 3820/9120
# [INFO] Đã xử lý 3840/9120
# [INFO] Đã xử lý 3860/9120
# [INFO] Đã xử lý 3880/9120
# [INFO] Đã xử lý 3900/9120
# [INFO] Đã xử lý 3920/9120
# [INFO] Đã xử lý 3940/9120
# [INFO] Đã xử lý 3960/9120
# [INFO] Đã xử lý 3980/9120
# [INFO] Đã xử lý 4000/9120
# [INFO] Đã xử lý 4020/9120
# [INFO] Đã xử lý 4040/9120
# [INFO] Đã xử lý 4060/9120
# [INFO] Đã xử lý 4080/9120
# [INFO] Đã xử lý 4100/9120
# [INFO] Đã xử lý 4120/9120
# [INFO] Đã xử lý 4140/9120
# [INFO] Đã xử lý 4160/9120
# [INFO] Đã xử lý 4180/9120
# [INFO] Đã xử lý 4200/9120
# [INFO] Đã xử lý 4220/9120
# [INFO] Đã xử lý 4240/9120
# [INFO] Đã xử lý 4260/9120
# [INFO] Đã xử lý 4280/9120
# [INFO] Đã xử lý 4300/9120
# [INFO] Đã xử lý 4320/9120
# [INFO] Đã xử lý 4340/9120
# [INFO] Đã xử lý 4360/9120
# [INFO] Đã xử lý 4380/9120
# [INFO] Đã xử lý 4400/9120
# [INFO] Đã xử lý 4420/9120
# [INFO] Đã xử lý 4440/9120
# [INFO] Đã xử lý 4460/9120
# [INFO] Đã xử lý 4480/9120
# [INFO] Đã xử lý 4500/9120
# [INFO] Đã xử lý 4520/9120
# [INFO] Đã xử lý 4540/9120
# [INFO] Đã xử lý 4560/9120
# [INFO] Đã xử lý 4580/9120
# [INFO] Đã xử lý 4600/9120
# [INFO] Đã xử lý 4620/9120
# [INFO] Đã xử lý 4640/9120
# [INFO] Đã xử lý 4660/9120
# [INFO] Đã xử lý 4680/9120
# [INFO] Đã xử lý 4700/9120
# [INFO] Đã xử lý 4720/9120
# [INFO] Đã xử lý 4740/9120
# [INFO] Đã xử lý 4760/9120
# [INFO] Đã xử lý 4780/9120
# [INFO] Đã xử lý 4800/9120
# [INFO] Đã xử lý 4820/9120
# [INFO] Đã xử lý 4840/9120
# [INFO] Đã xử lý 4860/9120
# [INFO] Đã xử lý 4880/9120
# [INFO] Đã xử lý 4900/9120
# [INFO] Đã xử lý 4920/9120
# [INFO] Đã xử lý 4940/9120
# [INFO] Đã xử lý 4960/9120
# [INFO] Đã xử lý 4980/9120
# [INFO] Đã xử lý 5000/9120
# [INFO] Đã xử lý 5020/9120
# [INFO] Đã xử lý 5040/9120
# [INFO] Đã xử lý 5060/9120
# [INFO] Đã xử lý 5080/9120
# [INFO] Đã xử lý 5100/9120
# [INFO] Đã xử lý 5120/9120
# [INFO] Đã xử lý 5140/9120
# [INFO] Đã xử lý 5160/9120
# [INFO] Đã xử lý 5180/9120
# [INFO] Đã xử lý 5200/9120
# [INFO] Đã xử lý 5220/9120
# [INFO] Đã xử lý 5240/9120
# [INFO] Đã xử lý 5260/9120
# [INFO] Đã xử lý 5280/9120
# [INFO] Đã xử lý 5300/9120
# [INFO] Đã xử lý 5320/9120
# [INFO] Đã xử lý 5340/9120
# [INFO] Đã xử lý 5360/9120
# [INFO] Đã xử lý 5380/9120
# [INFO] Đã xử lý 5400/9120
# [INFO] Đã xử lý 5420/9120
# [INFO] Đã xử lý 5440/9120
# [INFO] Đã xử lý 5460/9120
# [INFO] Đã xử lý 5480/9120
# [INFO] Đã xử lý 5500/9120
# [INFO] Đã xử lý 5520/9120
# [INFO] Đã xử lý 5540/9120
# [INFO] Đã xử lý 5560/9120
# [INFO] Đã xử lý 5580/9120
# [INFO] Đã xử lý 5600/9120
# [INFO] Đã xử lý 5620/9120
# [INFO] Đã xử lý 5640/9120
# [INFO] Đã xử lý 5660/9120
# [INFO] Đã xử lý 5680/9120
# [INFO] Đã xử lý 5700/9120
# [INFO] Đã xử lý 5720/9120
# [INFO] Đã xử lý 5740/9120
# [INFO] Đã xử lý 5760/9120
# [INFO] Đã xử lý 5780/9120
# [INFO] Đã xử lý 5800/9120
# [INFO] Đã xử lý 5820/9120
# [INFO] Đã xử lý 5840/9120
# [INFO] Đã xử lý 5860/9120
# [INFO] Đã xử lý 5880/9120
# [INFO] Đã xử lý 5900/9120
# [INFO] Đã xử lý 5920/9120
# [INFO] Đã xử lý 5940/9120
# [INFO] Đã xử lý 5960/9120
# [INFO] Đã xử lý 5980/9120
# [INFO] Đã xử lý 6000/9120
# [INFO] Đã xử lý 6020/9120
# [INFO] Đã xử lý 6040/9120
# [INFO] Đã xử lý 6060/9120
# [INFO] Đã xử lý 6080/9120
# [INFO] Đã xử lý 6100/9120
# [INFO] Đã xử lý 6120/9120
# [INFO] Đã xử lý 6140/9120
# [INFO] Đã xử lý 6160/9120
# [INFO] Đã xử lý 6180/9120
# [INFO] Đã xử lý 6200/9120
# [INFO] Đã xử lý 6220/9120
# [INFO] Đã xử lý 6240/9120
# [INFO] Đã xử lý 6260/9120
# [INFO] Đã xử lý 6280/9120
# [INFO] Đã xử lý 6300/9120
# [INFO] Đã xử lý 6320/9120
# [INFO] Đã xử lý 6340/9120
# [INFO] Đã xử lý 6360/9120
# [INFO] Đã xử lý 6380/9120
# [INFO] Đã xử lý 6400/9120
# [INFO] Đã xử lý 6420/9120
# [INFO] Đã xử lý 6440/9120
# [INFO] Đã xử lý 6460/9120
# [INFO] Đã xử lý 6480/9120
# [INFO] Đã xử lý 6500/9120
# [INFO] Đã xử lý 6520/9120
# [INFO] Đã xử lý 6540/9120
# [INFO] Đã xử lý 6560/9120
# [INFO] Đã xử lý 6580/9120
# [INFO] Đã xử lý 6600/9120
# [INFO] Đã xử lý 6620/9120
# [INFO] Đã xử lý 6640/9120
# [INFO] Đã xử lý 6660/9120
# [INFO] Đã xử lý 6680/9120
# [INFO] Đã xử lý 6700/9120
# [INFO] Đã xử lý 6720/9120
# [INFO] Đã xử lý 6740/9120
# [INFO] Đã xử lý 6760/9120
# [INFO] Đã xử lý 6780/9120
# [INFO] Đã xử lý 6800/9120
# [INFO] Đã xử lý 6820/9120
# [INFO] Đã xử lý 6840/9120
# [INFO] Đã xử lý 6860/9120
# [INFO] Đã xử lý 6880/9120
# [INFO] Đã xử lý 6900/9120
# [INFO] Đã xử lý 6920/9120
# [INFO] Đã xử lý 6940/9120
# [INFO] Đã xử lý 6960/9120
# [INFO] Đã xử lý 6980/9120
# [INFO] Đã xử lý 7000/9120
# [INFO] Đã xử lý 7020/9120
# [INFO] Đã xử lý 7040/9120
# [INFO] Đã xử lý 7060/9120
# [INFO] Đã xử lý 7080/9120
# [INFO] Đã xử lý 7100/9120
# [INFO] Đã xử lý 7120/9120
# [INFO] Đã xử lý 7140/9120
# [INFO] Đã xử lý 7160/9120
# [INFO] Đã xử lý 7180/9120
# [INFO] Đã xử lý 7200/9120
# [INFO] Đã xử lý 7220/9120
# [INFO] Đã xử lý 7240/9120
# [INFO] Đã xử lý 7260/9120
# [INFO] Đã xử lý 7280/9120
# [INFO] Đã xử lý 7300/9120
# [INFO] Đã xử lý 7320/9120
# [INFO] Đã xử lý 7340/9120
# [INFO] Đã xử lý 7360/9120
# [INFO] Đã xử lý 7380/9120
# [INFO] Đã xử lý 7400/9120
# [INFO] Đã xử lý 7420/9120
# [INFO] Đã xử lý 7440/9120
# [INFO] Đã xử lý 7460/9120
# [INFO] Đã xử lý 7480/9120
# [INFO] Đã xử lý 7500/9120
# [INFO] Đã xử lý 7520/9120
# [INFO] Đã xử lý 7540/9120
# [INFO] Đã xử lý 7560/9120
# [INFO] Đã xử lý 7580/9120
# [INFO] Đã xử lý 7600/9120
# [INFO] Đã xử lý 7620/9120
# [INFO] Đã xử lý 7640/9120
# [INFO] Đã xử lý 7660/9120
# [INFO] Đã xử lý 7680/9120
# [INFO] Đã xử lý 7700/9120
# [INFO] Đã xử lý 7720/9120
# [INFO] Đã xử lý 7740/9120
# [INFO] Đã xử lý 7760/9120
# [INFO] Đã xử lý 7780/9120
# [INFO] Đã xử lý 7800/9120
# [INFO] Đã xử lý 7820/9120
# [INFO] Đã xử lý 7840/9120
# [INFO] Đã xử lý 7860/9120
# [INFO] Đã xử lý 7880/9120
# [INFO] Đã xử lý 7900/9120
# [INFO] Đã xử lý 7920/9120
# [INFO] Đã xử lý 7940/9120
# [INFO] Đã xử lý 7960/9120
# [INFO] Đã xử lý 7980/9120
# [INFO] Đã xử lý 8000/9120
# [INFO] Đã xử lý 8020/9120
# [INFO] Đã xử lý 8040/9120
# [INFO] Đã xử lý 8060/9120
# [INFO] Đã xử lý 8080/9120
# [INFO] Đã xử lý 8100/9120
# [INFO] Đã xử lý 8120/9120
# [INFO] Đã xử lý 8140/9120
# [INFO] Đã xử lý 8160/9120
# [INFO] Đã xử lý 8180/9120
# [INFO] Đã xử lý 8200/9120
# [INFO] Đã xử lý 8220/9120
# [INFO] Đã xử lý 8240/9120
# [INFO] Đã xử lý 8260/9120
# [INFO] Đã xử lý 8280/9120
# [INFO] Đã xử lý 8300/9120
# [INFO] Đã xử lý 8320/9120
# [INFO] Đã xử lý 8340/9120
# [INFO] Đã xử lý 8360/9120
# [INFO] Đã xử lý 8380/9120
# [INFO] Đã xử lý 8400/9120
# [INFO] Đã xử lý 8420/9120
# [INFO] Đã xử lý 8440/9120
# [INFO] Đã xử lý 8460/9120
# [INFO] Đã xử lý 8480/9120
# [INFO] Đã xử lý 8500/9120
# [INFO] Đã xử lý 8520/9120
# [INFO] Đã xử lý 8540/9120
# [INFO] Đã xử lý 8560/9120
# [INFO] Đã xử lý 8580/9120
# [INFO] Đã xử lý 8600/9120
# [INFO] Đã xử lý 8620/9120
# [INFO] Đã xử lý 8640/9120
# [INFO] Đã xử lý 8660/9120
# [INFO] Đã xử lý 8680/9120
# [INFO] Đã xử lý 8700/9120
# [INFO] Đã xử lý 8720/9120
# [INFO] Đã xử lý 8740/9120
# [INFO] Đã xử lý 8760/9120
# [INFO] Đã xử lý 8780/9120
# [INFO] Đã xử lý 8800/9120
# [INFO] Đã xử lý 8820/9120
# [INFO] Đã xử lý 8840/9120
# [INFO] Đã xử lý 8860/9120
# [INFO] Đã xử lý 8880/9120
# [INFO] Đã xử lý 8900/9120
# [INFO] Đã xử lý 8920/9120
# [INFO] Đã xử lý 8940/9120
# [INFO] Đã xử lý 8960/9120
# [INFO] Đã xử lý 8980/9120
# [INFO] Đã xử lý 9000/9120
# [INFO] Đã xử lý 9020/9120
# [INFO] Đã xử lý 9040/9120
# [INFO] Đã xử lý 9060/9120
# [INFO] Đã xử lý 9080/9120
# [INFO] Đã xử lý 9100/9120
# [INFO] Đã xử lý 9120/9120

# %%
classLabels = ["Cerscospora", "Healthy", "Miner", "Phoma", "Rust"]

# Chia tách dữ liệu vào 02 tập, training: 75% và testing: 25%
(trainX, testX, trainY, testY) = train_test_split(data, labels,test_size=0.25, random_state=42)
# Chuyển dữ liệu nhãn ở số nguyên vào biểu diễn dưới dạng vectors
trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=1,)
optimizer = SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=True)

# %%
model = AlexNet.build(width=32, height=32, depth=3, classes=5)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=30, verbose=1)

model.save("miniVGGNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))

# %%
model = ShallowNet.build(width=32, height=32, depth=3, classes=5)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=30, verbose=1)

model.save("ShallowNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/30
# 107/107 [==============================] - 3s 17ms/step - loss: 1.3303 - accuracy: 0.4958 - val_loss: 0.7334 - val_accuracy: 0.7075
# Epoch 2/30
# 107/107 [==============================] - 1s 11ms/step - loss: 0.5570 - accuracy: 0.7765 - val_loss: 0.4874 - val_accuracy: 0.7982
# Epoch 3/30
# 107/107 [==============================] - 1s 7ms/step - loss: 0.3817 - accuracy: 0.8564 - val_loss: 0.3444 - val_accuracy: 0.8697
# Epoch 4/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.2960 - accuracy: 0.9003 - val_loss: 0.3091 - val_accuracy: 0.9013
# Epoch 5/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.2548 - accuracy: 0.9118 - val_loss: 0.3882 - val_accuracy: 0.8623
# Epoch 6/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.2308 - accuracy: 0.9225 - val_loss: 0.3030 - val_accuracy: 0.8842
# Epoch 7/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.1950 - accuracy: 0.9352 - val_loss: 0.2406 - val_accuracy: 0.9110
# Epoch 8/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.1602 - accuracy: 0.9471 - val_loss: 0.1954 - val_accuracy: 0.9316
# Epoch 9/30
# 107/107 [==============================] - 0s 5ms/step - loss: 0.1399 - accuracy: 0.9554 - val_loss: 0.1656 - val_accuracy: 0.9509
# Epoch 10/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.1267 - accuracy: 0.9613 - val_loss: 0.2090 - val_accuracy: 0.9232
# Epoch 11/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.1062 - accuracy: 0.9694 - val_loss: 0.1747 - val_accuracy: 0.9390
# Epoch 12/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0934 - accuracy: 0.9762 - val_loss: 0.1330 - val_accuracy: 0.9605
# Epoch 13/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0825 - accuracy: 0.9784 - val_loss: 0.1365 - val_accuracy: 0.9605
# Epoch 14/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0726 - accuracy: 0.9808 - val_loss: 0.1185 - val_accuracy: 0.9671
# Epoch 15/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0646 - accuracy: 0.9842 - val_loss: 0.1308 - val_accuracy: 0.9601
# Epoch 16/30
# 107/107 [==============================] - 0s 5ms/step - loss: 0.0559 - accuracy: 0.9874 - val_loss: 0.1021 - val_accuracy: 0.9671
# Epoch 17/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0485 - accuracy: 0.9890 - val_loss: 0.1000 - val_accuracy: 0.9741
# Epoch 18/30
# 107/107 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9909 - val_loss: 0.1035 - val_accuracy: 0.9763
# Epoch 19/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9924 - val_loss: 0.1033 - val_accuracy: 0.9728
# Epoch 20/30
# 107/107 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9937 - val_loss: 0.0889 - val_accuracy: 0.9789
# Epoch 21/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9949 - val_loss: 0.0881 - val_accuracy: 0.9785
# Epoch 22/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0287 - accuracy: 0.9956 - val_loss: 0.0842 - val_accuracy: 0.9820
# Epoch 23/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 0.9961 - val_loss: 0.0931 - val_accuracy: 0.9750
# Epoch 24/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0219 - accuracy: 0.9978 - val_loss: 0.0848 - val_accuracy: 0.9763
# Epoch 25/30
# 107/107 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9974 - val_loss: 0.0837 - val_accuracy: 0.9816
# Epoch 26/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0185 - accuracy: 0.9981 - val_loss: 0.0826 - val_accuracy: 0.9825
# Epoch 27/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0174 - accuracy: 0.9978 - val_loss: 0.0774 - val_accuracy: 0.9825
# Epoch 28/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0160 - accuracy: 0.9982 - val_loss: 0.0895 - val_accuracy: 0.9807
# Epoch 29/30
# 107/107 [==============================] - 1s 5ms/step - loss: 0.0143 - accuracy: 0.9985 - val_loss: 0.0724 - val_accuracy: 0.9833
# Epoch 30/30
# 107/107 [==============================] - 1s 6ms/step - loss: 0.0130 - accuracy: 0.9991 - val_loss: 0.0773 - val_accuracy: 0.9846
# [INFO]: Đánh giá model....
# 36/36 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#  Cerscospora       0.94      0.99      0.97       286
#      Healthy       1.00      1.00      1.00       742
#        Miner       0.98      0.99      0.99       663
#        Phoma       0.99      0.90      0.94       260
#         Rust       0.99      1.00      0.99       329
#
#     accuracy                           0.98      2280
#    macro avg       0.98      0.98      0.98      2280
# weighted avg       0.98      0.98      0.98      2280

# %%
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=5)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=30, verbose=1)

model.save("miniVGGNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/30
# 107/107 [==============================] - 3s 16ms/step - loss: 0.4509 - accuracy: 0.8402 - val_loss: 1.8851 - val_accuracy: 0.4675
# Epoch 2/30
# 107/107 [==============================] - 1s 11ms/step - loss: 0.1276 - accuracy: 0.9538 - val_loss: 1.0038 - val_accuracy: 0.6833
# Epoch 3/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0890 - accuracy: 0.9686 - val_loss: 0.8404 - val_accuracy: 0.7645
# Epoch 4/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0529 - accuracy: 0.9844 - val_loss: 0.0679 - val_accuracy: 0.9789
# Epoch 5/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0476 - accuracy: 0.9832 - val_loss: 0.0825 - val_accuracy: 0.9781
# Epoch 6/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0341 - accuracy: 0.9892 - val_loss: 0.0582 - val_accuracy: 0.9820
# Epoch 7/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0343 - accuracy: 0.9880 - val_loss: 0.0345 - val_accuracy: 0.9908
# Epoch 8/30
# 107/107 [==============================] - 1s 14ms/step - loss: 0.0357 - accuracy: 0.9886 - val_loss: 0.2344 - val_accuracy: 0.9250
# Epoch 9/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0165 - accuracy: 0.9950 - val_loss: 0.0730 - val_accuracy: 0.9781
# Epoch 10/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0127 - accuracy: 0.9958 - val_loss: 0.0135 - val_accuracy: 0.9965
# Epoch 11/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0173 - val_accuracy: 0.9947
# Epoch 12/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0088 - accuracy: 0.9974 - val_loss: 0.0213 - val_accuracy: 0.9939
# Epoch 13/30
# 107/107 [==============================] - 1s 11ms/step - loss: 0.0098 - accuracy: 0.9977 - val_loss: 0.0106 - val_accuracy: 0.9974
# Epoch 14/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0175 - accuracy: 0.9936 - val_loss: 0.0144 - val_accuracy: 0.9969
# Epoch 15/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0235 - val_accuracy: 0.9939
# Epoch 16/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0167 - accuracy: 0.9949 - val_loss: 0.0424 - val_accuracy: 0.9860
# Epoch 17/30
# 107/107 [==============================] - 1s 11ms/step - loss: 0.0089 - accuracy: 0.9968 - val_loss: 0.0321 - val_accuracy: 0.9890
# Epoch 18/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0048 - val_accuracy: 0.9987
# Epoch 19/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0073 - accuracy: 0.9975 - val_loss: 0.0133 - val_accuracy: 0.9965
# Epoch 20/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.0078 - val_accuracy: 0.9974
# Epoch 21/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0069 - val_accuracy: 0.9969
# Epoch 22/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0025 - accuracy: 0.9996 - val_loss: 0.0099 - val_accuracy: 0.9969
# Epoch 23/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0050 - val_accuracy: 0.9978
# Epoch 24/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0039 - val_accuracy: 0.9982
# Epoch 25/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0296 - val_accuracy: 0.9925
# Epoch 26/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0227 - val_accuracy: 0.9952
# Epoch 27/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0044 - accuracy: 0.9988 - val_loss: 0.0090 - val_accuracy: 0.9965
# Epoch 28/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0071 - val_accuracy: 0.9974
# Epoch 29/30
# 107/107 [==============================] - 1s 12ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0104 - val_accuracy: 0.9965
# Epoch 30/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0133 - val_accuracy: 0.9961
# [INFO]: Đánh giá model....
# 36/36 [==============================] - 0s 3ms/step
#               precision    recall  f1-score   support
#
#  Cerscospora       1.00      1.00      1.00       286
#      Healthy       1.00      1.00      1.00       742
#        Miner       0.99      1.00      0.99       663
#        Phoma       1.00      0.97      0.98       260
#         Rust       1.00      1.00      1.00       329
#
#     accuracy                           1.00      2280
#    macro avg       1.00      0.99      1.00      2280
# weighted avg       1.00      1.00      1.00      2280

# %%
model = ModVGGNet.build(width=32, height=32, depth=3, classes=5)
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=30, verbose=1)

model.save("modVGGNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/30
# 107/107 [==============================] - 3s 16ms/step - loss: 0.6029 - accuracy: 0.7958 - val_loss: 2.8798 - val_accuracy: 0.2632
# Epoch 2/30
# 107/107 [==============================] - 1s 14ms/step - loss: 0.2053 - accuracy: 0.9273 - val_loss: 1.1952 - val_accuracy: 0.6421
# Epoch 3/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.1291 - accuracy: 0.9522 - val_loss: 0.6774 - val_accuracy: 0.8443
# Epoch 4/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0983 - accuracy: 0.9689 - val_loss: 0.3490 - val_accuracy: 0.9127
# Epoch 5/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0738 - accuracy: 0.9741 - val_loss: 0.0648 - val_accuracy: 0.9794
# Epoch 6/30
# 107/107 [==============================] - 2s 14ms/step - loss: 0.0622 - accuracy: 0.9781 - val_loss: 0.0484 - val_accuracy: 0.9833
# Epoch 7/30
# 107/107 [==============================] - 2s 16ms/step - loss: 0.0448 - accuracy: 0.9849 - val_loss: 0.0237 - val_accuracy: 0.9921
# Epoch 8/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0377 - accuracy: 0.9867 - val_loss: 0.0138 - val_accuracy: 0.9961
# Epoch 9/30
# 107/107 [==============================] - 1s 14ms/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.0533 - val_accuracy: 0.9829
# Epoch 10/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.0238 - val_accuracy: 0.9921
# Epoch 11/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0476 - accuracy: 0.9844 - val_loss: 0.0698 - val_accuracy: 0.9785
# Epoch 12/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0324 - accuracy: 0.9902 - val_loss: 0.0253 - val_accuracy: 0.9912
# Epoch 13/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.0088 - val_accuracy: 0.9956
# Epoch 14/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0211 - accuracy: 0.9923 - val_loss: 0.0232 - val_accuracy: 0.9939
# Epoch 15/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0542 - accuracy: 0.9817 - val_loss: 1.6145 - val_accuracy: 0.7487
# Epoch 16/30
# 107/107 [==============================] - 2s 16ms/step - loss: 0.0354 - accuracy: 0.9886 - val_loss: 0.0143 - val_accuracy: 0.9943
# Epoch 17/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0208 - accuracy: 0.9940 - val_loss: 0.0113 - val_accuracy: 0.9965
# Epoch 18/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0240 - val_accuracy: 0.9921
# Epoch 19/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0149 - val_accuracy: 0.9943
# Epoch 20/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0152 - accuracy: 0.9946 - val_loss: 0.1222 - val_accuracy: 0.9684
# Epoch 21/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 0.0405 - val_accuracy: 0.9829
# Epoch 22/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0287 - val_accuracy: 0.9904
# Epoch 23/30
# 107/107 [==============================] - 2s 15ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0334 - val_accuracy: 0.9899
# Epoch 24/30
# 107/107 [==============================] - 2s 16ms/step - loss: 0.0148 - accuracy: 0.9939 - val_loss: 0.0067 - val_accuracy: 0.9974
# Epoch 25/30
# 107/107 [==============================] - 2s 18ms/step - loss: 0.0115 - accuracy: 0.9968 - val_loss: 0.0078 - val_accuracy: 0.9965
# Epoch 26/30
# 107/107 [==============================] - 2s 17ms/step - loss: 0.0070 - accuracy: 0.9981 - val_loss: 0.0062 - val_accuracy: 0.9974
# Epoch 27/30
# 107/107 [==============================] - 1s 14ms/step - loss: 0.0059 - accuracy: 0.9985 - val_loss: 0.0140 - val_accuracy: 0.9952
# Epoch 28/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0050 - accuracy: 0.9978 - val_loss: 0.0109 - val_accuracy: 0.9952
# Epoch 29/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0044 - accuracy: 0.9982 - val_loss: 0.0090 - val_accuracy: 0.9974
# Epoch 30/30
# 107/107 [==============================] - 1s 13ms/step - loss: 0.0047 - accuracy: 0.9982 - val_loss: 0.0203 - val_accuracy: 0.9961
# [INFO]: Đánh giá model....
# 36/36 [==============================] - 0s 4ms/step
#               precision    recall  f1-score   support
#
#  Cerscospora       1.00      1.00      1.00       286
#      Healthy       1.00      1.00      1.00       742
#        Miner       0.99      1.00      0.99       663
#        Phoma       1.00      0.97      0.98       260
#         Rust       1.00      1.00      1.00       329
#
#     accuracy                           1.00      2280
#    macro avg       1.00      0.99      0.99      2280
# weighted avg       1.00      1.00      1.00      2280
