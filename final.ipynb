# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/note/LeafDD
# Out:
# /content/drive/MyDrive/note/LeafDD

# %%
# !ls
# Out:
# Apple		   datasets	     final.ipynb      ShallowNet.hdf5
# Apple.tar.xz	   datasets2	     miniVGGNet.hdf5
# CoffeeLeaf.tar.xz  datasets2.tar.xz  modVGGNet.hdf5

# %%
# !tar -xvf datasets2.tar.xz

# %%
# !ls datasets2/
# Out:
# 'Apple Black rot'	      'Peach Bacterial spot'
# 'Apple cedar rust'	      'Peach Healthy'
# 'Apple Healthy'		      'Potato Early blight'
# 'Apple Scab'		      'Potato Healthy'
# 'Bell pepper Bacterial spot'  'Potato Late blight'
# 'Bell pepper Healthy'	      'Tomato Bacterial spot'
# 'Cherry Healthy'	      'Tomato Early blight'
# 'Cherry Powdery mildew'       'Tomato Healthy'
# 'Corn Common rust'	      'Tomato Late blight'
# 'Corn Gray leaf spot'	      'Tomato Leaf Mold'
# 'Corn Healthy'		      'Tomato Mosaic virus'
# 'Corn Northern Leaf Blight'   'Tomato Septoria leaf spot'
# 'Grape Black Measles'	      'Tomato Spider mites'
# 'Grape Black rot'	      'Tomato Target Spot'
# 'Grape Healthy'		      'Tomato Yellow Leaf Curl Virus'
# 'Grape Isariopsis Leaf Spot'

# %%
import numpy as np
import tensorflow as tf
import cv2, os
from keras.models import Sequential
from keras.layers import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
from keras.utils.image_utils import img_to_array
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imutils import paths
from keras.optimizers import SGD, schedules

# %%
class SimpleDatasetLoader:
    def __init__(self, preprocessors=None):
        # Lưu ảnh tiền xử lý
        self.preprocessors = preprocessors

        # Nếu bước tiền xử lý là None thì khởi tạo danh sách rỗng
        if self.preprocessors is None:
            self.preprocessors = []

    def load(self, imagePaths, verbose=-1):
        # Khởi tạo danh sách các đặc trưng và nhãn
        data = []
        labels = []

        # Lặp qua tất cả ảnh đầu vào
        for (i, imagePath) in enumerate(imagePaths):
            # Nạp ảnh và trích xuất nhãn từ đường dẫn định dạng
            # /path/to/dataset/{class}/{image}.jpg
            image = cv2.imread(imagePath)
            label = imagePath.split(os.path.sep)[-2]
            # check to see if our preprocessors are not None
            if self.preprocessors is not None:
                # Lặp qua tất cả tiền xử lý và áp dụng cho mỗi ảnh
                for p in self.preprocessors:
                    image = p.preprocess(image)
            # Mỗi ảnh được xử lý là vector đặc trưng bằng cách
            # cập nhật danh sách dữ liệu cùng với nhãn
            data.append(image)
            labels.append(label)

            # Hiển thị ảnh cập nhật
            if verbose > 0 and i > 0 and (i + 1) % verbose == 0:
               print("[INFO] Đã xử lý {}/{}".format(i + 1,len(imagePaths)))
                # Trả về dữ liệu kiểu tuple gồm dữ liệu và nhãn
        return (np.array(data), np.array(labels))

# %%
class ImageToArrayPreprocessor:  # Tạo lớp để chuyển ảnh --> mảng
    def __init__(self, dataFormat=None):
        # Lưu ảnh đã được định dạng
        self.dataFormat = dataFormat

    def preprocess(self, image): # Định nghĩa phương thức preprocess trả về mảng
        # Hàm img_to_array của Keras
        return img_to_array(image, data_format=self.dataFormat)
class SimplePreprocessor:
    def __init__(self, width, height, inter=cv2.INTER_AREA):
        # Lưu image width, height và interpolation
        self.width = width
        self.height = height
        self.inter = inter

    def preprocess(self, image):
        # Trả về ảnh có kích thước đã thay đổi
        return cv2.resize(image, (self.width, self.height), interpolation=self.inter)

# %%
class ShallowNet:
    @staticmethod
    def build(width, height, depth, classes):
        # khởi tạo mô hình
        # height, width, depth: tương ứng 3 chiều của dữ liệu ảnh đầu vào
        # classes: tổng số lớp mà mạng dự đoán, phụ thuộc vào dữ liệu
        # Dữ liệu Animal: 3 lớp; Dữ liệu CIFAR-10: 10 lớp

        model = Sequential()
        inputShape = (height, width, depth)

        if K.image_data_format() == "channels_first":
            inputShape = (depth, height, width)

        # Định nghĩa mạng CONV => RELU layer
        model.add(Conv2D(32, (3, 3), padding="same",input_shape = inputShape))
        model.add(Activation("relu"))

        # Bộ phân lớp sử dụng hàm softmax
        model.add(Flatten())       # Chuyển thành vector
        model.add(Dense(classes))  # Định nghĩa Full Connected layer
        model.add(Activation("softmax"))   # Kích hoạt hàm softmax để phân lớp
        # Trả về model kiến trúc mạng
        return model

# %%
class MiniVGGNet:
  @staticmethod
  def build(width, height, depth, classes):
      # Khởi tạo mô hình, shape ảnh đầu vào và số kênh của ảnh đầu vào
      model = Sequential()
      input_shape = (height, width, depth)
      channel_dim = -1  # chỉ số của số kênh ảnh đầu vào
                        # giá trị -1 ý muốn nói chỉ số kênh nằm cuối cùng
                        # của danh sách chứa dữ liệu ảnh đầu vào

      # sử dụng 'channels_first' để cập nhật shape và số kênh ảnh đầu vào
      if K.image_data_format() == 'channels_first':
          input_shape = (depth, height, width)
          channel_dim = 1

      # Chuỗi layer đầu tiên  CONV => RELU => CONV => RELU => POOL
      model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(Conv2D(32, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(MaxPooling2D(pool_size=(2, 2)))
      model.add(Dropout(0.25))

      # Chuỗi layer thứ hai CONV => RELU => CONV => RELU => POOL
      model.add(Conv2D(64, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(Conv2D(64, (3, 3), padding='same'))
      model.add(Activation('relu'))
      model.add(BatchNormalization(axis=channel_dim))
      model.add(MaxPooling2D(pool_size=(2, 2)))
      model.add(Dropout(0.25))

      # Thiết lập FC thứ nhất => RELU layers
      model.add(Flatten())
      model.add(Dense(512))
      model.add(Activation('relu'))
      model.add(BatchNormalization())
      model.add(Dropout(0.25))   # Dropout 50%

      # THiết lập FC thứ hai => Hàm phân lớp Softmax
      model.add(Dense(classes))
      model.add(Activation('softmax'))

      # Trả về kiến trúc mạng/mô hình
      return model

# %%
class ModVGGNet:
    @staticmethod
    def build(width, height, depth, classes):
        # Khởi tạo mô hình, shape ảnh đầu vào và số kênh của ảnh đầu vào
        model = Sequential()
        input_shape = (height, width, depth)
        channel_dim = -1  # chỉ số của số kênh ảnh đầu vào
                          # giá trị -1 ý muốn nói chỉ số kênh nằm cuối cùng
                          # của danh sách chứa dữ liệu ảnh đầu vào

        # sử dụng 'channels_first' để cập nhật shape và số kênh ảnh đầu vào
        if K.image_data_format() == 'channels_first':
            input_shape = (depth, height, width)
            channel_dim = 1

        # Chuỗi layer đầu tiên  CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(32, (3, 3), padding='same', input_shape=input_shape))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(32, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Chuỗi layer thứ hai CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(64, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(64, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Chuỗi layer thứ ba CONV => RELU => CONV => RELU => POOL
        model.add(Conv2D(128, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(Conv2D(128, (3, 3), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization(axis=channel_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.25))

        # Thiết lập FC thứ nhất => RELU layers
        model.add(Flatten())
        model.add(Dense(1024))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))   # Dropout 50%

        # THiết lập FC thứ hai => Hàm phân lớp Softmax
        model.add(Dense(classes))
        model.add(Activation('softmax'))

        # Trả về kiến trúc mạng/mô hình
        return model

# %%
vb = 64

imagePaths = list(paths.list_images("datasets2/"))

# Bước 1. Chuẩn bị dữ liệu
# Khởi tạo tiền xử lý ảnh
sp = SimplePreprocessor(32, 32) # Thiết lập kích thước ảnh 32 x 32
iap = ImageToArrayPreprocessor() # Gọi hàm để chuyển ảnh sang mảng

# Nạp dataset từ đĩa
print("[INFO] Nạp ảnh...")

sdl = SimpleDatasetLoader(preprocessors=[sp, iap])
(data, labels) = sdl.load(imagePaths, verbose=vb)
data = data.astype("float") / 255.0
# Out:
# [INFO] Nạp ảnh...
# [INFO] Đã xử lý 64/25329
# [INFO] Đã xử lý 128/25329
# [INFO] Đã xử lý 192/25329
# [INFO] Đã xử lý 256/25329
# [INFO] Đã xử lý 320/25329
# [INFO] Đã xử lý 384/25329
# [INFO] Đã xử lý 448/25329
# [INFO] Đã xử lý 512/25329
# [INFO] Đã xử lý 576/25329
# [INFO] Đã xử lý 640/25329
# [INFO] Đã xử lý 704/25329
# [INFO] Đã xử lý 768/25329
# [INFO] Đã xử lý 832/25329
# [INFO] Đã xử lý 896/25329
# [INFO] Đã xử lý 960/25329
# [INFO] Đã xử lý 1024/25329
# [INFO] Đã xử lý 1088/25329
# [INFO] Đã xử lý 1152/25329
# [INFO] Đã xử lý 1216/25329
# [INFO] Đã xử lý 1280/25329
# [INFO] Đã xử lý 1344/25329
# [INFO] Đã xử lý 1408/25329
# [INFO] Đã xử lý 1472/25329
# [INFO] Đã xử lý 1536/25329
# [INFO] Đã xử lý 1600/25329
# [INFO] Đã xử lý 1664/25329
# [INFO] Đã xử lý 1728/25329
# [INFO] Đã xử lý 1792/25329
# [INFO] Đã xử lý 1856/25329
# [INFO] Đã xử lý 1920/25329
# [INFO] Đã xử lý 1984/25329
# [INFO] Đã xử lý 2048/25329
# [INFO] Đã xử lý 2112/25329
# [INFO] Đã xử lý 2176/25329
# [INFO] Đã xử lý 2240/25329
# [INFO] Đã xử lý 2304/25329
# [INFO] Đã xử lý 2368/25329
# [INFO] Đã xử lý 2432/25329
# [INFO] Đã xử lý 2496/25329
# [INFO] Đã xử lý 2560/25329
# [INFO] Đã xử lý 2624/25329
# [INFO] Đã xử lý 2688/25329
# [INFO] Đã xử lý 2752/25329
# [INFO] Đã xử lý 2816/25329
# [INFO] Đã xử lý 2880/25329
# [INFO] Đã xử lý 2944/25329
# [INFO] Đã xử lý 3008/25329
# [INFO] Đã xử lý 3072/25329
# [INFO] Đã xử lý 3136/25329
# [INFO] Đã xử lý 3200/25329
# [INFO] Đã xử lý 3264/25329
# [INFO] Đã xử lý 3328/25329
# [INFO] Đã xử lý 3392/25329
# [INFO] Đã xử lý 3456/25329
# [INFO] Đã xử lý 3520/25329
# [INFO] Đã xử lý 3584/25329
# [INFO] Đã xử lý 3648/25329
# [INFO] Đã xử lý 3712/25329
# [INFO] Đã xử lý 3776/25329
# [INFO] Đã xử lý 3840/25329
# [INFO] Đã xử lý 3904/25329
# [INFO] Đã xử lý 3968/25329
# [INFO] Đã xử lý 4032/25329
# [INFO] Đã xử lý 4096/25329
# [INFO] Đã xử lý 4160/25329
# [INFO] Đã xử lý 4224/25329
# [INFO] Đã xử lý 4288/25329
# [INFO] Đã xử lý 4352/25329
# [INFO] Đã xử lý 4416/25329
# [INFO] Đã xử lý 4480/25329
# [INFO] Đã xử lý 4544/25329
# [INFO] Đã xử lý 4608/25329
# [INFO] Đã xử lý 4672/25329
# [INFO] Đã xử lý 4736/25329
# [INFO] Đã xử lý 4800/25329
# [INFO] Đã xử lý 4864/25329
# [INFO] Đã xử lý 4928/25329
# [INFO] Đã xử lý 4992/25329
# [INFO] Đã xử lý 5056/25329
# [INFO] Đã xử lý 5120/25329
# [INFO] Đã xử lý 5184/25329
# [INFO] Đã xử lý 5248/25329
# [INFO] Đã xử lý 5312/25329
# [INFO] Đã xử lý 5376/25329
# [INFO] Đã xử lý 5440/25329
# [INFO] Đã xử lý 5504/25329
# [INFO] Đã xử lý 5568/25329
# [INFO] Đã xử lý 5632/25329
# [INFO] Đã xử lý 5696/25329
# [INFO] Đã xử lý 5760/25329
# [INFO] Đã xử lý 5824/25329
# [INFO] Đã xử lý 5888/25329
# [INFO] Đã xử lý 5952/25329
# [INFO] Đã xử lý 6016/25329
# [INFO] Đã xử lý 6080/25329
# [INFO] Đã xử lý 6144/25329
# [INFO] Đã xử lý 6208/25329
# [INFO] Đã xử lý 6272/25329
# [INFO] Đã xử lý 6336/25329
# [INFO] Đã xử lý 6400/25329
# [INFO] Đã xử lý 6464/25329
# [INFO] Đã xử lý 6528/25329
# [INFO] Đã xử lý 6592/25329
# [INFO] Đã xử lý 6656/25329
# [INFO] Đã xử lý 6720/25329
# [INFO] Đã xử lý 6784/25329
# [INFO] Đã xử lý 6848/25329
# [INFO] Đã xử lý 6912/25329
# [INFO] Đã xử lý 6976/25329
# [INFO] Đã xử lý 7040/25329
# [INFO] Đã xử lý 7104/25329
# [INFO] Đã xử lý 7168/25329
# [INFO] Đã xử lý 7232/25329
# [INFO] Đã xử lý 7296/25329
# [INFO] Đã xử lý 7360/25329
# [INFO] Đã xử lý 7424/25329
# [INFO] Đã xử lý 7488/25329
# [INFO] Đã xử lý 7552/25329
# [INFO] Đã xử lý 7616/25329
# [INFO] Đã xử lý 7680/25329
# [INFO] Đã xử lý 7744/25329
# [INFO] Đã xử lý 7808/25329
# [INFO] Đã xử lý 7872/25329
# [INFO] Đã xử lý 7936/25329
# [INFO] Đã xử lý 8000/25329
# [INFO] Đã xử lý 8064/25329
# [INFO] Đã xử lý 8128/25329
# [INFO] Đã xử lý 8192/25329
# [INFO] Đã xử lý 8256/25329
# [INFO] Đã xử lý 8320/25329
# [INFO] Đã xử lý 8384/25329
# [INFO] Đã xử lý 8448/25329
# [INFO] Đã xử lý 8512/25329
# [INFO] Đã xử lý 8576/25329
# [INFO] Đã xử lý 8640/25329
# [INFO] Đã xử lý 8704/25329
# [INFO] Đã xử lý 8768/25329
# [INFO] Đã xử lý 8832/25329
# [INFO] Đã xử lý 8896/25329
# [INFO] Đã xử lý 8960/25329
# [INFO] Đã xử lý 9024/25329
# [INFO] Đã xử lý 9088/25329
# [INFO] Đã xử lý 9152/25329
# [INFO] Đã xử lý 9216/25329
# [INFO] Đã xử lý 9280/25329
# [INFO] Đã xử lý 9344/25329
# [INFO] Đã xử lý 9408/25329
# [INFO] Đã xử lý 9472/25329
# [INFO] Đã xử lý 9536/25329
# [INFO] Đã xử lý 9600/25329
# [INFO] Đã xử lý 9664/25329
# [INFO] Đã xử lý 9728/25329
# [INFO] Đã xử lý 9792/25329
# [INFO] Đã xử lý 9856/25329
# [INFO] Đã xử lý 9920/25329
# [INFO] Đã xử lý 9984/25329
# [INFO] Đã xử lý 10048/25329
# [INFO] Đã xử lý 10112/25329
# [INFO] Đã xử lý 10176/25329
# [INFO] Đã xử lý 10240/25329
# [INFO] Đã xử lý 10304/25329
# [INFO] Đã xử lý 10368/25329
# [INFO] Đã xử lý 10432/25329
# [INFO] Đã xử lý 10496/25329
# [INFO] Đã xử lý 10560/25329
# [INFO] Đã xử lý 10624/25329
# [INFO] Đã xử lý 10688/25329
# [INFO] Đã xử lý 10752/25329
# [INFO] Đã xử lý 10816/25329
# [INFO] Đã xử lý 10880/25329
# [INFO] Đã xử lý 10944/25329
# [INFO] Đã xử lý 11008/25329
# [INFO] Đã xử lý 11072/25329
# [INFO] Đã xử lý 11136/25329
# [INFO] Đã xử lý 11200/25329
# [INFO] Đã xử lý 11264/25329
# [INFO] Đã xử lý 11328/25329
# [INFO] Đã xử lý 11392/25329
# [INFO] Đã xử lý 11456/25329
# [INFO] Đã xử lý 11520/25329
# [INFO] Đã xử lý 11584/25329
# [INFO] Đã xử lý 11648/25329
# [INFO] Đã xử lý 11712/25329
# [INFO] Đã xử lý 11776/25329
# [INFO] Đã xử lý 11840/25329
# [INFO] Đã xử lý 11904/25329
# [INFO] Đã xử lý 11968/25329
# [INFO] Đã xử lý 12032/25329
# [INFO] Đã xử lý 12096/25329
# [INFO] Đã xử lý 12160/25329
# [INFO] Đã xử lý 12224/25329
# [INFO] Đã xử lý 12288/25329
# [INFO] Đã xử lý 12352/25329
# [INFO] Đã xử lý 12416/25329
# [INFO] Đã xử lý 12480/25329
# [INFO] Đã xử lý 12544/25329
# [INFO] Đã xử lý 12608/25329
# [INFO] Đã xử lý 12672/25329
# [INFO] Đã xử lý 12736/25329
# [INFO] Đã xử lý 12800/25329
# [INFO] Đã xử lý 12864/25329
# [INFO] Đã xử lý 12928/25329
# [INFO] Đã xử lý 12992/25329
# [INFO] Đã xử lý 13056/25329
# [INFO] Đã xử lý 13120/25329
# [INFO] Đã xử lý 13184/25329
# [INFO] Đã xử lý 13248/25329
# [INFO] Đã xử lý 13312/25329
# [INFO] Đã xử lý 13376/25329
# [INFO] Đã xử lý 13440/25329
# [INFO] Đã xử lý 13504/25329
# [INFO] Đã xử lý 13568/25329
# [INFO] Đã xử lý 13632/25329
# [INFO] Đã xử lý 13696/25329
# [INFO] Đã xử lý 13760/25329
# [INFO] Đã xử lý 13824/25329
# [INFO] Đã xử lý 13888/25329
# [INFO] Đã xử lý 13952/25329
# [INFO] Đã xử lý 14016/25329
# [INFO] Đã xử lý 14080/25329
# [INFO] Đã xử lý 14144/25329
# [INFO] Đã xử lý 14208/25329
# [INFO] Đã xử lý 14272/25329
# [INFO] Đã xử lý 14336/25329
# [INFO] Đã xử lý 14400/25329
# [INFO] Đã xử lý 14464/25329
# [INFO] Đã xử lý 14528/25329
# [INFO] Đã xử lý 14592/25329
# [INFO] Đã xử lý 14656/25329
# [INFO] Đã xử lý 14720/25329
# [INFO] Đã xử lý 14784/25329
# [INFO] Đã xử lý 14848/25329
# [INFO] Đã xử lý 14912/25329
# [INFO] Đã xử lý 14976/25329
# [INFO] Đã xử lý 15040/25329
# [INFO] Đã xử lý 15104/25329
# [INFO] Đã xử lý 15168/25329
# [INFO] Đã xử lý 15232/25329
# [INFO] Đã xử lý 15296/25329
# [INFO] Đã xử lý 15360/25329
# [INFO] Đã xử lý 15424/25329
# [INFO] Đã xử lý 15488/25329
# [INFO] Đã xử lý 15552/25329
# [INFO] Đã xử lý 15616/25329
# [INFO] Đã xử lý 15680/25329
# [INFO] Đã xử lý 15744/25329
# [INFO] Đã xử lý 15808/25329
# [INFO] Đã xử lý 15872/25329
# [INFO] Đã xử lý 15936/25329
# [INFO] Đã xử lý 16000/25329
# [INFO] Đã xử lý 16064/25329
# [INFO] Đã xử lý 16128/25329
# [INFO] Đã xử lý 16192/25329
# [INFO] Đã xử lý 16256/25329
# [INFO] Đã xử lý 16320/25329
# [INFO] Đã xử lý 16384/25329
# [INFO] Đã xử lý 16448/25329
# [INFO] Đã xử lý 16512/25329
# [INFO] Đã xử lý 16576/25329
# [INFO] Đã xử lý 16640/25329
# [INFO] Đã xử lý 16704/25329
# [INFO] Đã xử lý 16768/25329
# [INFO] Đã xử lý 16832/25329
# [INFO] Đã xử lý 16896/25329
# [INFO] Đã xử lý 16960/25329
# [INFO] Đã xử lý 17024/25329
# [INFO] Đã xử lý 17088/25329
# [INFO] Đã xử lý 17152/25329
# [INFO] Đã xử lý 17216/25329
# [INFO] Đã xử lý 17280/25329
# [INFO] Đã xử lý 17344/25329
# [INFO] Đã xử lý 17408/25329
# [INFO] Đã xử lý 17472/25329
# [INFO] Đã xử lý 17536/25329
# [INFO] Đã xử lý 17600/25329
# [INFO] Đã xử lý 17664/25329
# [INFO] Đã xử lý 17728/25329
# [INFO] Đã xử lý 17792/25329
# [INFO] Đã xử lý 17856/25329
# [INFO] Đã xử lý 17920/25329
# [INFO] Đã xử lý 17984/25329
# [INFO] Đã xử lý 18048/25329
# [INFO] Đã xử lý 18112/25329
# [INFO] Đã xử lý 18176/25329
# [INFO] Đã xử lý 18240/25329
# [INFO] Đã xử lý 18304/25329
# [INFO] Đã xử lý 18368/25329
# [INFO] Đã xử lý 18432/25329
# [INFO] Đã xử lý 18496/25329
# [INFO] Đã xử lý 18560/25329
# [INFO] Đã xử lý 18624/25329
# [INFO] Đã xử lý 18688/25329
# [INFO] Đã xử lý 18752/25329
# [INFO] Đã xử lý 18816/25329
# [INFO] Đã xử lý 18880/25329
# [INFO] Đã xử lý 18944/25329
# [INFO] Đã xử lý 19008/25329
# [INFO] Đã xử lý 19072/25329
# [INFO] Đã xử lý 19136/25329
# [INFO] Đã xử lý 19200/25329
# [INFO] Đã xử lý 19264/25329
# [INFO] Đã xử lý 19328/25329
# [INFO] Đã xử lý 19392/25329
# [INFO] Đã xử lý 19456/25329
# [INFO] Đã xử lý 19520/25329
# [INFO] Đã xử lý 19584/25329
# [INFO] Đã xử lý 19648/25329
# [INFO] Đã xử lý 19712/25329
# [INFO] Đã xử lý 19776/25329
# [INFO] Đã xử lý 19840/25329
# [INFO] Đã xử lý 19904/25329
# [INFO] Đã xử lý 19968/25329
# [INFO] Đã xử lý 20032/25329
# [INFO] Đã xử lý 20096/25329
# [INFO] Đã xử lý 20160/25329
# [INFO] Đã xử lý 20224/25329
# [INFO] Đã xử lý 20288/25329
# [INFO] Đã xử lý 20352/25329
# [INFO] Đã xử lý 20416/25329
# [INFO] Đã xử lý 20480/25329
# [INFO] Đã xử lý 20544/25329
# [INFO] Đã xử lý 20608/25329
# [INFO] Đã xử lý 20672/25329
# [INFO] Đã xử lý 20736/25329
# [INFO] Đã xử lý 20800/25329
# [INFO] Đã xử lý 20864/25329
# [INFO] Đã xử lý 20928/25329
# [INFO] Đã xử lý 20992/25329
# [INFO] Đã xử lý 21056/25329
# [INFO] Đã xử lý 21120/25329
# [INFO] Đã xử lý 21184/25329
# [INFO] Đã xử lý 21248/25329
# [INFO] Đã xử lý 21312/25329
# [INFO] Đã xử lý 21376/25329
# [INFO] Đã xử lý 21440/25329
# [INFO] Đã xử lý 21504/25329
# [INFO] Đã xử lý 21568/25329
# [INFO] Đã xử lý 21632/25329
# [INFO] Đã xử lý 21696/25329
# [INFO] Đã xử lý 21760/25329
# [INFO] Đã xử lý 21824/25329
# [INFO] Đã xử lý 21888/25329
# [INFO] Đã xử lý 21952/25329
# [INFO] Đã xử lý 22016/25329
# [INFO] Đã xử lý 22080/25329
# [INFO] Đã xử lý 22144/25329
# [INFO] Đã xử lý 22208/25329
# [INFO] Đã xử lý 22272/25329
# [INFO] Đã xử lý 22336/25329
# [INFO] Đã xử lý 22400/25329
# [INFO] Đã xử lý 22464/25329
# [INFO] Đã xử lý 22528/25329
# [INFO] Đã xử lý 22592/25329
# [INFO] Đã xử lý 22656/25329
# [INFO] Đã xử lý 22720/25329
# [INFO] Đã xử lý 22784/25329
# [INFO] Đã xử lý 22848/25329
# [INFO] Đã xử lý 22912/25329
# [INFO] Đã xử lý 22976/25329
# [INFO] Đã xử lý 23040/25329
# [INFO] Đã xử lý 23104/25329
# [INFO] Đã xử lý 23168/25329
# [INFO] Đã xử lý 23232/25329
# [INFO] Đã xử lý 23296/25329
# [INFO] Đã xử lý 23360/25329
# [INFO] Đã xử lý 23424/25329
# [INFO] Đã xử lý 23488/25329
# [INFO] Đã xử lý 23552/25329
# [INFO] Đã xử lý 23616/25329
# [INFO] Đã xử lý 23680/25329
# [INFO] Đã xử lý 23744/25329
# [INFO] Đã xử lý 23808/25329
# [INFO] Đã xử lý 23872/25329
# [INFO] Đã xử lý 23936/25329
# [INFO] Đã xử lý 24000/25329
# [INFO] Đã xử lý 24064/25329
# [INFO] Đã xử lý 24128/25329
# [INFO] Đã xử lý 24192/25329
# [INFO] Đã xử lý 24256/25329
# [INFO] Đã xử lý 24320/25329
# [INFO] Đã xử lý 24384/25329
# [INFO] Đã xử lý 24448/25329
# [INFO] Đã xử lý 24512/25329
# [INFO] Đã xử lý 24576/25329
# [INFO] Đã xử lý 24640/25329
# [INFO] Đã xử lý 24704/25329
# [INFO] Đã xử lý 24768/25329
# [INFO] Đã xử lý 24832/25329
# [INFO] Đã xử lý 24896/25329
# [INFO] Đã xử lý 24960/25329
# [INFO] Đã xử lý 25024/25329
# [INFO] Đã xử lý 25088/25329
# [INFO] Đã xử lý 25152/25329
# [INFO] Đã xử lý 25216/25329
# [INFO] Đã xử lý 25280/25329

# %%
classLabels = ['Apple Black rot', 'Apple cedar rust', 'Apple Healthy', 'Apple Scab', 'Bell pepper Bacterial spot', 'Bell pepper Healthy',
                'Cherry Healthy', 'Cherry Powdery mildew', 'Corn Common rust', 'Corn Gray leaf spot', 'Corn Healthy', 'Corn Northern Leaf Blight',
                'Grape Black Measles', 'Grape Black rot', 'Grape Healthy', 'Grape Isariopsis Leaf Spot', 'Peach Bacterial spot', 'Peach Healthy',
                'Potato Early blight', 'Potato Healthy', 'Potato Late blight', 'Tomato Bacterial spot', 'Tomato Early blight', 'Tomato Healthy',
                'Tomato Late blight', 'Tomato Leaf Mold', 'Tomato Mosaic virus', 'Tomato Septoria leaf spot', 'Tomato Spider mites', 'Tomato Target Spot',
                'Tomato Yellow Leaf Curl Virus']

# Chia tách dữ liệu vào 02 tập, training: 75% và testing: 25%
(trainX, testX, trainY, testY) = train_test_split(data, labels,test_size=0.25, random_state=42)
# Chuyển dữ liệu nhãn ở số nguyên vào biểu diễn dưới dạng vectors
trainY = LabelBinarizer().fit_transform(trainY)
testY = LabelBinarizer().fit_transform(testY)

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-2,
    decay_steps=10000,
    decay_rate=1,)
optimizer = SGD(learning_rate=lr_schedule, momentum=0.9, nesterov=True)

ep = 10

# %%
model = ShallowNet.build(width=32, height=32, depth=3, classes=len(classLabels))
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=ep, verbose=1)

model.save("ShallowNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/10
# 297/297 [==============================] - 25s 80ms/step - loss: 2.0713 - accuracy: 0.4285 - val_loss: 1.5396 - val_accuracy: 0.5846
# Epoch 2/10
# 297/297 [==============================] - 19s 63ms/step - loss: 1.3335 - accuracy: 0.6337 - val_loss: 1.3131 - val_accuracy: 0.6327
# Epoch 3/10
# 297/297 [==============================] - 19s 65ms/step - loss: 1.0771 - accuracy: 0.6996 - val_loss: 1.1440 - val_accuracy: 0.6766
# Epoch 4/10
# 297/297 [==============================] - 19s 64ms/step - loss: 0.9035 - accuracy: 0.7481 - val_loss: 0.9836 - val_accuracy: 0.7270
# Epoch 5/10
# 297/297 [==============================] - 19s 64ms/step - loss: 0.7740 - accuracy: 0.7839 - val_loss: 1.0296 - val_accuracy: 0.7275
# Epoch 6/10
# 297/297 [==============================] - 20s 66ms/step - loss: 0.6694 - accuracy: 0.8092 - val_loss: 1.0004 - val_accuracy: 0.7199
# Epoch 7/10
# 297/297 [==============================] - 19s 64ms/step - loss: 0.5768 - accuracy: 0.8377 - val_loss: 0.8749 - val_accuracy: 0.7543
# Epoch 8/10
# 297/297 [==============================] - 19s 62ms/step - loss: 0.4992 - accuracy: 0.8559 - val_loss: 0.8697 - val_accuracy: 0.7639
# Epoch 9/10
# 297/297 [==============================] - 18s 59ms/step - loss: 0.4235 - accuracy: 0.8807 - val_loss: 0.8644 - val_accuracy: 0.7677
# Epoch 10/10
# 297/297 [==============================] - 21s 70ms/step - loss: 0.3598 - accuracy: 0.8973 - val_loss: 0.8505 - val_accuracy: 0.7729
# [INFO]: Đánh giá model....
# 99/99 [==============================] - 2s 18ms/step
#                                precision    recall  f1-score   support
#
#               Apple Black rot       0.85      0.66      0.75       194
#              Apple cedar rust       0.61      0.84      0.71       229
#                 Apple Healthy       0.78      0.66      0.71       172
#                    Apple Scab       0.61      0.68      0.64       141
#    Bell pepper Bacterial spot       0.59      0.74      0.66       192
#           Bell pepper Healthy       0.88      0.72      0.80       242
#                Cherry Healthy       0.80      0.93      0.86       153
#         Cherry Powdery mildew       0.83      0.85      0.84       189
#              Corn Common rust       0.98      0.92      0.95       186
#           Corn Gray leaf spot       0.65      0.64      0.65       149
#                  Corn Healthy       0.96      0.99      0.98       185
#     Corn Northern Leaf Blight       0.75      0.78      0.76       212
#           Grape Black Measles       0.84      0.93      0.88       219
#               Grape Black rot       0.87      0.73      0.80       194
#                 Grape Healthy       0.85      0.88      0.86       154
#    Grape Isariopsis Leaf Spot       0.93      0.95      0.94       179
#          Peach Bacterial spot       0.79      0.82      0.80       277
#                 Peach Healthy       0.77      0.85      0.81       146
#           Potato Early blight       0.90      0.85      0.88       212
#                Potato Healthy       0.73      0.59      0.65       143
#            Potato Late blight       0.79      0.63      0.70       228
#         Tomato Bacterial spot       0.80      0.82      0.81       279
#           Tomato Early blight       0.56      0.42      0.48       186
#                Tomato Healthy       0.85      0.84      0.85       241
#            Tomato Late blight       0.57      0.69      0.63       219
#              Tomato Leaf Mold       0.58      0.76      0.66       186
#           Tomato Mosaic virus       0.87      0.81      0.84       154
#     Tomato Septoria leaf spot       0.63      0.60      0.62       218
#           Tomato Spider mites       0.66      0.82      0.73       224
#            Tomato Target Spot       0.91      0.56      0.69       200
# Tomato Yellow Leaf Curl Virus       0.92      0.85      0.88       430
#
#                      accuracy                           0.77      6333
#                     macro avg       0.78      0.77      0.77      6333
#                  weighted avg       0.78      0.77      0.77      6333

# %%
model = MiniVGGNet.build(width=32, height=32, depth=3, classes=len(classLabels))
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=ep, verbose=1)

model.save("miniVGGNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/10
# 297/297 [==============================] - 168s 562ms/step - loss: 1.5265 - accuracy: 0.5745 - val_loss: 3.9006 - val_accuracy: 0.2678
# Epoch 2/10
# 297/297 [==============================] - 179s 602ms/step - loss: 0.7526 - accuracy: 0.7746 - val_loss: 0.8521 - val_accuracy: 0.7355
# Epoch 3/10
# 297/297 [==============================] - 181s 610ms/step - loss: 0.5418 - accuracy: 0.8314 - val_loss: 0.7402 - val_accuracy: 0.7841
# Epoch 4/10
# 297/297 [==============================] - 170s 573ms/step - loss: 0.4230 - accuracy: 0.8704 - val_loss: 0.4914 - val_accuracy: 0.8487
# Epoch 5/10
# 297/297 [==============================] - 179s 604ms/step - loss: 0.3440 - accuracy: 0.8909 - val_loss: 0.6953 - val_accuracy: 0.7973
# Epoch 6/10
# 297/297 [==============================] - 170s 574ms/step - loss: 0.2666 - accuracy: 0.9174 - val_loss: 0.3840 - val_accuracy: 0.8811
# Epoch 7/10
# 297/297 [==============================] - 173s 581ms/step - loss: 0.2300 - accuracy: 0.9256 - val_loss: 0.6485 - val_accuracy: 0.8025
# Epoch 8/10
# 297/297 [==============================] - 171s 576ms/step - loss: 0.1934 - accuracy: 0.9373 - val_loss: 0.3938 - val_accuracy: 0.8784
# Epoch 9/10
# 297/297 [==============================] - 162s 545ms/step - loss: 0.1654 - accuracy: 0.9483 - val_loss: 0.3160 - val_accuracy: 0.9090
# Epoch 10/10
# 297/297 [==============================] - 171s 575ms/step - loss: 0.1367 - accuracy: 0.9577 - val_loss: 0.5909 - val_accuracy: 0.8333
# [INFO]: Đánh giá model....
# 99/99 [==============================] - 10s 99ms/step
#                                precision    recall  f1-score   support
#
#               Apple Black rot       0.99      0.62      0.77       194
#              Apple cedar rust       0.85      0.93      0.89       229
#                 Apple Healthy       0.89      0.77      0.82       172
#                    Apple Scab       0.72      0.70      0.71       141
#    Bell pepper Bacterial spot       0.93      0.65      0.76       192
#           Bell pepper Healthy       0.63      0.96      0.77       242
#                Cherry Healthy       0.94      0.69      0.80       153
#         Cherry Powdery mildew       0.81      0.96      0.88       189
#              Corn Common rust       0.99      0.97      0.98       186
#           Corn Gray leaf spot       0.74      0.90      0.81       149
#                  Corn Healthy       0.93      1.00      0.97       185
#     Corn Northern Leaf Blight       0.96      0.77      0.86       212
#           Grape Black Measles       0.97      0.86      0.91       219
#               Grape Black rot       0.85      0.77      0.81       194
#                 Grape Healthy       0.82      0.91      0.86       154
#    Grape Isariopsis Leaf Spot       0.79      0.98      0.87       179
#          Peach Bacterial spot       0.95      0.89      0.92       277
#                 Peach Healthy       0.97      0.80      0.88       146
#           Potato Early blight       0.76      0.98      0.86       212
#                Potato Healthy       0.91      0.64      0.75       143
#            Potato Late blight       0.94      0.68      0.79       228
#         Tomato Bacterial spot       0.90      0.90      0.90       279
#           Tomato Early blight       0.67      0.78      0.72       186
#                Tomato Healthy       0.85      0.95      0.90       241
#            Tomato Late blight       0.71      0.86      0.78       219
#              Tomato Leaf Mold       0.65      0.89      0.75       186
#           Tomato Mosaic virus       0.95      0.77      0.85       154
#     Tomato Septoria leaf spot       0.82      0.60      0.69       218
#           Tomato Spider mites       0.70      0.91      0.79       224
#            Tomato Target Spot       0.88      0.41      0.55       200
# Tomato Yellow Leaf Curl Virus       0.89      0.98      0.93       430
#
#                      accuracy                           0.83      6333
#                     macro avg       0.85      0.82      0.82      6333
#                  weighted avg       0.85      0.83      0.83      6333

# %%
model = ModVGGNet.build(width=32, height=32, depth=3, classes=len(classLabels))
model.compile(loss="categorical_crossentropy", optimizer=optimizer, metrics=["accuracy"])

print("[INFO]: Đang trainning....")
H = model.fit(trainX, trainY, validation_data=(testX, testY), batch_size=64, epochs=ep, verbose=1)

model.save("modVGGNet.hdf5")
# model.summary()

print("[INFO]: Đánh giá model....")
predictions = model.predict(testX, batch_size=64)
print(classification_report(testY.argmax(axis=1), predictions.argmax(axis=1), target_names=classLabels))
# Out:
# [INFO]: Đang trainning....
# Epoch 1/10
# 297/297 [==============================] - 222s 741ms/step - loss: 1.7528 - accuracy: 0.5301 - val_loss: 5.1148 - val_accuracy: 0.2176
# Epoch 2/10
# 297/297 [==============================] - 222s 748ms/step - loss: 0.8825 - accuracy: 0.7382 - val_loss: 1.5433 - val_accuracy: 0.6011
# Epoch 3/10
# 297/297 [==============================] - 230s 775ms/step - loss: 0.6702 - accuracy: 0.7953 - val_loss: 0.6910 - val_accuracy: 0.7878
# Epoch 4/10
# 297/297 [==============================] - 229s 772ms/step - loss: 0.5280 - accuracy: 0.8383 - val_loss: 0.5403 - val_accuracy: 0.8438
# Epoch 5/10
# 297/297 [==============================] - 224s 755ms/step - loss: 0.4281 - accuracy: 0.8649 - val_loss: 0.4630 - val_accuracy: 0.8642
# Epoch 6/10
# 297/297 [==============================] - 225s 756ms/step - loss: 0.3661 - accuracy: 0.8850 - val_loss: 0.5255 - val_accuracy: 0.8386
# Epoch 7/10
# 297/297 [==============================] - 229s 770ms/step - loss: 0.3193 - accuracy: 0.8972 - val_loss: 0.3680 - val_accuracy: 0.8903
# Epoch 8/10
# 297/297 [==============================] - 229s 771ms/step - loss: 0.2621 - accuracy: 0.9137 - val_loss: 0.4996 - val_accuracy: 0.8601
# Epoch 9/10
# 297/297 [==============================] - 238s 801ms/step - loss: 0.2259 - accuracy: 0.9249 - val_loss: 0.3169 - val_accuracy: 0.9094
# Epoch 10/10
# 297/297 [==============================] - 231s 779ms/step - loss: 0.2066 - accuracy: 0.9314 - val_loss: 0.3284 - val_accuracy: 0.9087
# [INFO]: Đánh giá model....
# 99/99 [==============================] - 16s 154ms/step
#                                precision    recall  f1-score   support
#
#               Apple Black rot       0.95      0.90      0.92       194
#              Apple cedar rust       0.82      0.93      0.87       229
#                 Apple Healthy       0.98      0.72      0.83       172
#                    Apple Scab       0.96      0.82      0.89       141
#    Bell pepper Bacterial spot       0.93      0.81      0.87       192
#           Bell pepper Healthy       0.86      0.95      0.90       242
#                Cherry Healthy       0.95      0.94      0.95       153
#         Cherry Powdery mildew       0.96      0.98      0.97       189
#              Corn Common rust       0.97      0.98      0.98       186
#           Corn Gray leaf spot       0.83      0.87      0.85       149
#                  Corn Healthy       0.96      0.99      0.98       185
#     Corn Northern Leaf Blight       0.88      0.88      0.88       212
#           Grape Black Measles       0.97      0.89      0.93       219
#               Grape Black rot       0.84      0.95      0.90       194
#                 Grape Healthy       0.99      0.94      0.96       154
#    Grape Isariopsis Leaf Spot       0.94      0.96      0.95       179
#          Peach Bacterial spot       0.97      0.91      0.94       277
#                 Peach Healthy       0.83      0.92      0.87       146
#           Potato Early blight       0.88      0.98      0.93       212
#                Potato Healthy       0.89      0.86      0.88       143
#            Potato Late blight       0.89      0.89      0.89       228
#         Tomato Bacterial spot       0.90      0.93      0.92       279
#           Tomato Early blight       0.77      0.84      0.80       186
#                Tomato Healthy       0.98      0.92      0.95       241
#            Tomato Late blight       0.90      0.89      0.89       219
#              Tomato Leaf Mold       0.83      0.92      0.88       186
#           Tomato Mosaic virus       0.88      0.99      0.93       154
#     Tomato Septoria leaf spot       0.88      0.77      0.82       218
#           Tomato Spider mites       0.97      0.89      0.93       224
#            Tomato Target Spot       0.81      0.88      0.84       200
# Tomato Yellow Leaf Curl Virus       0.98      0.96      0.97       430
#
#                      accuracy                           0.91      6333
#                     macro avg       0.91      0.91      0.91      6333
#                  weighted avg       0.91      0.91      0.91      6333
